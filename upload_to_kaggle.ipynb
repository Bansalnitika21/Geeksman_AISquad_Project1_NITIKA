# %% [markdown]
# <a href="https://colab.research.google.com/github/Bansalnitika21/Geeksman_AISquad_Project1_NITIKA/blob/devil/upload_to_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**To upload data set on kaggle**

# %% [markdown]
# ###**KAGGLE.JSON**

# %% [markdown]
# First step is to upload you kaggle.json file that you downloaded after
#
# generating api token on kaggle!

# %%
from google.colab import files
my_file=files.upload()
# Out:
#      <input type="file" id="files-851fe7a7-2280-4f70-a247-f4f1717fbf5c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-851fe7a7-2280-4f70-a247-f4f1717fbf5c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %% [markdown]
# **Run this code for setting up of environment variable.**
#
# This code will first import os in colab ,
# pandas is imported to read the json file that is in .csv format

# %%
import os
import pandas as pd
cred = pd.read_json("kaggle.json",lines=True)
os.environ['KAGGLE_USERNAME'] = cred.iloc[0][0]
os.environ['KAGGLE_KEY'] = cred.iloc[0][1]

# %% [markdown]
# ###**MOUNTING DRIVE**
#
#
# IT'S COMPLICATED THOUGH!!!!
#
#  so i have planned to show you why this method is complicated :/

# %% [markdown]
# It is necessary so that in next notebook we can directly access out dataset without the need of uploading .json file again.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# For making folder of the name waste_classification!!

# %%
os.makedirs("/content/drive/My Drive/Geeksman_AISquad_Project1_NITIKA/waste_classification",exist_ok=True)

# %% [markdown]
# ### **LOCATING IN DRIVE**

# %% [markdown]
# **The location is in drive**
#
# we can shutil.move but some people are not that much familiar with this language and the use of cd command is easily available on youtube, and i used this command many times because it shifts the loaction step by step else an error will occur saying too many requests or something like this!

# %%
cd drive
# Out:
# /content/drive

# %% [markdown]
# **The loaction is drive/My Drive**

# %%
cd My Drive
# Out:
# /content/drive/My Drive

# %% [markdown]
# **The loaction is drive/My Drive/Geeksman_AISquad_Project1_NITIKA**

# %%
cd Geeksman_AISquad_Project1_NITIKA
# Out:
# /content/drive/My Drive/Geeksman_AISquad_Project1_NITIKA

# %% [markdown]
# **The loaction is
# drive/My Drive/Geeksman_AISquad_Project1_NITIKA/waste_classification**

# %%
cd waste_classification
# Out:
# /content/drive/My Drive/Geeksman_AISquad_Project1_NITIKA/waste_classification

# %% [markdown]
# **For checking where the pointer is**

# %%
# !pwd
# Out:
# /content/drive/My Drive/Geeksman_AISquad_Project1_NITIKA/waste_classification

# %% [markdown]
# ##**DOWNLOADING ZIP FILE**

# %% [markdown]
# **This cell will download the .ZIP from the given location to colab**

# %%
# !kaggle datasets download -d techsash/waste-classification-data
# Out:
# ...
#  96% 410M/427M [00:06<00:00, 74.2MB/s]
# 100% 427M/427M [00:06<00:00, 68.6MB/s]

# %% [markdown]
# ## **UPLOADING DATA ON KAGGLE USING 2 LINES OF CODE**

# %% [markdown]
# **Runing this cell will download a dataset-metadata.json at content location**

# %%
# !kaggle datasets init -p /content
# Out:
# Data package template written to: /content/dataset-metadata.json

# %% [markdown]
# **Running this cell will create a dataset on kaggle**
#
# **DONOT RUN THIS CELL AS THE DATASET IS ALREADY CREATED ON MY KAGGLE ACCOUNT**
#
#
# First edit the dataset-metadata.json file as followed:
#
# **{**
#
#  **"licenses": [**
#
#       {
#         "name": "CC0-1.0"
#       }
#
#  **],**
#
#   **"id": "bansalnitika21/dataset",**
#
#   **"title": "WASTE CLASS"**
#
# **}**
#
# To avoid default slug detected, please change values before uploading ERROR

# %%
# !kaggle datasets create  --dir-mode zip -p /content
# Out:
# Starting upload for file .config.zip
# ...
# 100% 6.75k/6.75k [00:00<00:00, 16.7kB/s]
# Upload successful: .config.zip (7KB)
# Starting upload for file waste-classification-data.zip
# 100% 427M/427M [00:04<00:00, 111MB/s]
# Upload successful: waste-classification-data.zip (427MB)
# Starting upload for file kaggle.json
# 100% 70.0/70.0 [00:00<00:00, 327B/s]
# Upload successful: kaggle.json (70B)
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/cli.py", line 51, in main
#     out = args.func(**command_args)
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 1468, in dataset_create_new_cli
#     dir_mode)
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 1444, in dataset_create_new
#     self.upload_files(request, resources, folder, quiet, dir_mode)
# ...

# %% [markdown]
# ## **DISPLAYING DATA IN COLAB AND DRIVE**

# %% [markdown]
# **This cell is for .zip file that was created by api download command**
#
# when you will run this cell the .zip file will get unzipped and waste_classification folder will get filled with desired images

# %%
# !unzip "*.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/DATASET/TRAIN/R/R_55.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_550.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5500.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5501.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5502.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5503.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5504.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5505.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5506.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5507.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5508.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5509.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_551.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5510.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5511.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5512.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5513.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5514.jpg
#   inflating: dataset/DATASET/TRAIN/R/R_5515.jpg
# ...

# %% [markdown]
# This cell is for listing out what a folder is containing
#
# you can also try replacing DATASET with dataset and check they both are displaying different outputs

# %%
os.listdir("DATASET")
# Out:
# ['TEST', 'TRAIN']
